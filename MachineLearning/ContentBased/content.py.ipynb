# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
movie_attributes=pd.read_csv('bollywood_text_2010-2019.csv')
movie_attributes.head()
movie_title=pd.read_csv('bollywood_2010-2019.csv')
movie_title.head()


movie_attributes=pd.merge(movie_attributes,movie_title,on='imdb_id')
movie_attributes.head()
# Out:
#      imdb_id                                              story  \
# 0  tt5013008  Fraud Saiyyan is the story of a con artist in ...
# 1  tt8291224  Divided over five chapters  the film chronicle...
# 2  tt9472208  The story revolves around a cricket match betw...
# 3  tt6986710  Based on the memoir by Indian policy analyst S...
# 4  tt6028796  While gay rights and marriage equality has bee...
#
#                                              summary tagline  \
# 0  Fraud Saiyyan is the story of a con artist in ...     NaN
# 1  Indian army special forces execute a covert op...     NaN
# 2  The story of Battalion 609 revolves around a c...     NaN
# 3  Explores Manmohan Singh's tenure as the Prime ...     NaN
# 4  Under the 'Evening Shadows'  truth often plays...     NaN
#
#                                               actors        wins_nominations  \
# 0  Arshad Warsi|Saurabh Shukla|Flora Saini|Sara L...                     NaN
# ...

# %%
def get_title_from_index(index):
	return movie_attributes[movie_attributes.index==index]["title"].values[0]

def get_index_from_title(title):
	return movie_attributes[movie_attributes.title==title]["index"].values[0]

# %%
movie_attributes['new_col']=range(0,len(movie_attributes))
movie_attributes=movie_attributes.reset_index()
movie_attributes.head()
# Out:
#    index    imdb_id                                              story  \
# 0      0  tt5013008  Fraud Saiyyan is the story of a con artist in ...
# 1      1  tt8291224  Divided over five chapters  the film chronicle...
# 2      2  tt9472208  The story revolves around a cricket match betw...
# 3      3  tt6986710  Based on the memoir by Indian policy analyst S...
# 4      4  tt6028796  While gay rights and marriage equality has bee...
#
#                                              summary tagline  \
# 0  Fraud Saiyyan is the story of a con artist in ...     NaN
# 1  Indian army special forces execute a covert op...     NaN
# 2  The story of Battalion 609 revolves around a c...     NaN
# 3  Explores Manmohan Singh's tenure as the Prime ...     NaN
# 4  Under the 'Evening Shadows'  truth often plays...     NaN
#
#                                               actors        wins_nominations  \
# 0  Arshad Warsi|Saurabh Shukla|Flora Saini|Sara L...                     NaN
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity




features=['story','summary','tagline','actors']
#create a column in df which combines all selected features
for feature in features:
	movie_attributes[feature]=movie_attributes[feature].fillna('')

def combine_features(row):
	try:
		return row['story']+" "+row['summary']+" "+row['tagline']+" "+row['actors']
	except:
		print("error",row)

movie_attributes["combine_features"]=movie_attributes.apply(combine_features,axis=1) #each row individually
print("Combined features: ",movie_attributes["combine_features"].head())


#create count matrix from this new combined column
cv=CountVectorizer()
count_matrix=cv.fit_transform(movie_attributes["combine_features"])
# Out:
# Combined features:  0    Fraud Saiyyan is the story of a con artist in ...
# 1    Divided over five chapters  the film chronicle...
# 2    The story revolves around a cricket match betw...
# 3    Based on the memoir by Indian policy analyst S...
# 4    While gay rights and marriage equality has bee...
# Name: combine_features, dtype: object

# %%
#compute the cosine similarity based on the count_matrix
import csv
cosine_sim=cosine_similarity(count_matrix)
j=1
while j:
    #print("Enter Movie for which you need recommendation.")
    movie_user_likes=input()
    

    #get the index of this movie from its title
    movie_index=get_index_from_title(movie_user_likes)
    similar_movies=list(enumerate(cosine_sim[movie_index]))

    #get a list of similar movies in descending order
    sorted_similar_movies=sorted(similar_movies,key=lambda x:x[1],reverse=True)[1:]
    i=0
    for movie in sorted_similar_movies:
        print(get_title_from_index(movie[0]))
        i=i+1
        if(i>10):
            break
    print("Want to check another movie?(y/n)")
    choice=input().upper()
    if(choice!='Y'):
        j=0
# Out:
# n
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-06c7a9c76608> in <module>
#       9
#      10     #get the index of this movie from its title
# ---> 11     movie_index=get_index_from_title(movie_user_likes)
#      12     similar_movies=list(enumerate(cosine_sim[movie_index]))
#      13
#
# <ipython-input-4-12cb9721563b> in get_index_from_title(title)
#       3
#       4 def get_index_from_title(title):
# ----> 5         return movie_attributes[movie_attributes.title==title]["index"].values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
