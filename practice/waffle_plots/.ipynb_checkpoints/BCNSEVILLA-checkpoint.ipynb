# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib as mpl
from pywaffle import Waffle
from highlight_text import fig_text

# %%
df=pd.read_csv('touches.csv')
#edit the player names
df['Player']=df['Player'].str.split('\\',expand=True)[0]

df=df.sort_values(by=['Touches'],ascending=False)

df=df.drop(15)

df=df.drop('Touches',axis=1)

#transpose
df=df.T

df.columns=df.iloc[0]
df=df.drop('Player')

df=df.drop('Live')

my_list=df.columns.values.tolist()

df=pd.DataFrame(df,columns=my_list)

# %%
df
# Out:
#         Sergi Roberto Sergio Busquets Lionel Messi Gerard Piqué Ronald Araújo  \
# Def Pen             3               1            0           16            12
# Def 3rd            33              16            3           45            34
# Mid 3rd            39              55           50           40            36
# Att 3rd            24              21           35            0             0
# Att Pen             3               2            6            0             0
#
#         Frenkie de Jong Jordi Alba Neto Philippe Coutinho Ansu Fati  \
# Def Pen               2          2   43                 1         0
# Def 3rd              12         23   48                 3         4
# Mid 3rd              37         27    0                31        17
# Att 3rd              16         16    0                15        23
# Att Pen               2          0    0                 1         5
#
#         Francisco Trincão Miralem Pjani? Antoine Griezmann Sergiño Dest Pedri
# Def Pen                 0              0                 0            0     1
# Def 3rd                 2              8                 4            6     2
# Mid 3rd                14              7                 6            5     8
# Att 3rd                10              7                 9            5     8
# Att Pen                 4              0                 2            1     0

# %%
fig=plt.figure(
    FigureClass=Waffle,
    values=df.iloc[:,0],
    labels=list(df.index),
    rows=10,
    title={
        'label':my_list[0]
    },
    figsize=(7,7),
    
    
)
# Out:
# <Waffle size 504x504 with 1 Axes>

# %%
fig=plt.figure(
    FigureClass=Waffle,
    rows=10,
    figsize=(10,10),
    plots={
        '331':{
            'values':df.iloc[:,0],
            'title':{
                'label':my_list[0],
                'color':'white',
                'loc':'left'
            }
        },
        '332':{
            'values':df.iloc[:,1],
            'title':{
                'label':my_list[1],
                'color':'white',
                'loc':'left'
            }
        },
        '333':{
            'values':df.iloc[:,2],
            'title':{
                'label':my_list[2],
                'color':'white',
                'loc':'left'
            }
        },
        '334':{
            'values':df.iloc[:,3],
            'title':{
                'label':my_list[3],
                'color':'white',
                'loc':'left'
            }
        },
        '335':{
            'values':df.iloc[:,4],
            'title':{
                'label':my_list[4],
                'color':'white',
                'loc':'left'
            }
        },
        '336':{
            'values':df.iloc[:,5],
            'title':{
                'label':my_list[5],
                'color':'white',
                'loc':'left'
            }
        },
        '337':{
            'values':df.iloc[:,6],
            'title':{
                'label':my_list[6],
                'color':'white',
                'loc':'left'
            }
        },
        '338':{
            'values':df.iloc[:,7],
            'title':{
                'label':my_list[7],
                'color':'white',
                'loc':'left'
            }
        },
        '339':{
            'values':df.iloc[:,8],
            'title':{
                'label':my_list[8],
                'color':'white',
                'loc':'left'
            }
        },
        
        
    },    

)


fig_text(
    s='Where Barcelona Players Made Tuches vs Sevilla \n <Def 3rd>, <Mid 3rd>,<Att 3rd>, +<Att Pen>\n ',
    x=.01,y=.99,
    fontsize=18,
    color='lightgrey',
    #highlight_colors=[]
    
)

fig.patch.set_facecolor('#313332')
# Out:
# <Waffle size 720x720 with 9 Axes>
